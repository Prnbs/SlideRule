# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
df_sf = pd.read_csv("sf_crime_report.csv", parse_dates=['date'], infer_datetime_format=True)
df_sf.head()
# Out:
#    incidnt_num        category                               descript  \
# 0    140099416   VEHICLE THEFT           STOLEN AND RECOVERED VEHICLE
# 1    140092426         ASSAULT                                BATTERY
# 2    140092410  SUSPICIOUS OCC                  SUSPICIOUS OCCURRENCE
# 3    140092341  OTHER OFFENSES  DRIVERS LICENSE, SUSPENDED OR REVOKED
# 4    140092573   DRUG/NARCOTIC  POSSESSION OF NARCOTICS PARAPHERNALIA
#
#   day_of_week                date   time pd_district      resolution  \
# 0      Friday 2014-01-31 08:00:00  17:00   INGLESIDE            NONE
# 1      Friday 2014-01-31 08:00:00  17:45     TARAVAL   ARREST, CITED
# 2      Friday 2014-01-31 08:00:00  15:30        PARK            NONE
# 3      Friday 2014-01-31 08:00:00  17:50     CENTRAL   ARREST, CITED
# 4      Friday 2014-01-31 08:00:00  19:20    SOUTHERN  ARREST, BOOKED
#
#                     address         lon        lat  \
# 0    0 Block of GARRISON AV -122.413624  37.709726
# 1      100 Block of FONT BL -122.473706  37.715488
# 2      0 Block of CASTRO ST -122.435719  37.768689
# 3  JEFFERSON ST / POWELL ST -122.412527  37.808625
# 4       0 Block of GRACE ST -122.414634  37.775081
#
#                                 location         cleaned_date  id
# 0   (37.709725805163, -122.413623946206)  2014-01-31T17:00:00   1
# 1   (37.7154876086057, -122.47370623066)  2014-01-31T17:45:00   2
# 2  (37.7686887134351, -122.435718550322)  2014-01-31T15:30:00   3
# 3  (37.8086250595467, -122.412527239682)  2014-01-31T17:50:00   4
# 4  (37.7750814399634, -122.414633686589)  2014-01-31T19:20:00   5

# %%
#1 Busiest day of the week
df_sf.groupby('day_of_week').size().plot(kind='bar',legend=False)

# %%
#2 Most popular crime
df_sf.groupby('category').size().plot(kind='bar', legend=False)

# %%
#3 How does SFPD resolve these crimes?
df_sf.groupby('resolution').size().plot(kind='bar', legend=False)

# %%
#4 What kind of crime's go unreolved the most?
df_unreolved = df_sf[df_sf.resolution=='NONE']
df_unreolved.groupby('category').size().plot(kind='bar')

# %%
#5 Which police district is most crime ridden
df_sf.groupby('pd_district').size().plot(kind='bar')

# %%
#6 Southern district has the most crimes
# Let's see what kind of crimes these are
df_southern = df_sf[df_sf.pd_district=='SOUTHERN']
df_southern.groupby(df_southern.category).size().plot(kind='bar')

# %%
# Can we find the top 10 addresses in Southern district that are particularly shady?
# TBD

# %%
# the above graph seems to be representative of the crimes in SF in general
# Now lets see what kind of crimes hapens in Park which is the least crime ridden (figuratively speaking)
df_park = df_sf[df_sf.pd_district=='PARK']
df_park.groupby(df_park.category).size().plot(kind='bar')

# %%
# This is slightly different from the crime stats in Southern, there are more vandalism and warrants in Park
#7 How are missing person cases reolved?
df_missing = df_sf[df_sf.category=='MISSING PERSON']
df_missing.groupby('resolution').size().plot(kind='bar')

# %%
# Did criminals relax on christmas?
# For this let's see what the crime distribution is on Nov24, Dec24 and Jan 24

# %%
#8 Did criminals relax on christmas?
df_24th_day_of_month = df_sf[df_sf.date.dt.day == 25]
df_24th_day_of_month = df_24th_day_of_month[['category', 'date']]
df_24th_day_of_month = df_24th_day_of_month.groupby([df_24th_day_of_month.date.dt.month, df_24th_day_of_month.category]).count()
df_24th_day_of_month.unstack(0).plot(kind='bar')

# %%
# So criminals do want to be good on Christmas at least
# So let's ask the same question for crime resolution
df_24th_day_of_month = df_sf[df_sf.date.dt.day == 25]
df_24th_day_of_month = df_24th_day_of_month[['resolution', 'date']]
df_24th_day_of_month = df_24th_day_of_month.groupby([df_24th_day_of_month.date.dt.month, df_24th_day_of_month.resolution]).count()
df_24th_day_of_month.unstack(0).plot(kind='bar')

# %%
# Can't really conclude anything from this since crime is low on Christmas anyway
# Now let's look at number of crimes committed each week
df_crime_by_Week = df_sf
df_crime_by_Week['week'] = df_sf.date.dt.week
df_crime_by_Week = df_crime_by_Week.sort('date', ascending=True)
df_crime_by_Week.groupby('week')

# %%
# Week 44 and Week 5 are the extremes ends of this dataset and as such they may not contain all the data that they could have.
# So looking at this the week of christmas is still the week with lowest incidents of reported crime
# Let's look at the crime wave between Dec 23nd and Dec 29th i.e. the week of christmas
df_xmas_week = df_sf[df_sf.date.dt.week == 52]
df_xmas_week.groupby(df_xmas_week.date.dt.date).size().plot(kind='bar')

# %%
#9 Is there a week when the SFPD was more active?
df_resolution = df_sf[['resolution', 'date']]
df_resolution = df_resolution[df_resolution.resolution != 'NONE'].sort('date')
df_resolution['week'] = df_resolution.date.dt.week
df_resolution.groupby(df_resolution.week)
