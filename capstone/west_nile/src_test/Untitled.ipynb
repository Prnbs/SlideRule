# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
x = np.arange(-5, 5, 0.1)
y = np.arange(-5, 5, 0.1)
xx, yy = np.meshgrid(x, y, sparse=True)
z = np.sin(xx**2 + yy**2) / (xx**2 + yy**2)
h = plt.contourf(x,y,z)
h
# Out:
# <matplotlib.contour.QuadContourSet instance at 0x000000000B202C88>
